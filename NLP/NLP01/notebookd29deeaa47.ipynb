# %%
# !tar -xzvf korean-english-park.train.tar.gz
# !pip install tensorflow
# Out:
# tar (child): korean-english-park.train.tar.gz: Cannot open: No such file or directory
# tar (child): Error is not recoverable: exiting now
# tar: Child returned status 2
# tar: Error is not recoverable: exiting now
# Requirement already satisfied: tensorflow in /usr/local/lib/python3.12/dist-packages (2.19.0)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (25.12.19)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (0.7.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (18.1.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (3.4.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from tensorflow) (26.0)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0dev,>=3.20.3 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (5.29.5)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (2.32.4)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from tensorflow) (75.2.0)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (1.17.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (3.3.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (4.15.0)
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (2.1.1)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (1.78.1)
# Requirement already satisfied: tensorboard~=2.19.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (2.19.0)
# Requirement already satisfied: keras>=3.5.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (3.10.0)
# Requirement already satisfied: numpy<2.2.0,>=1.26.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (2.0.2)
# Requirement already satisfied: h5py>=3.11.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (3.15.1)
# Requirement already satisfied: ml-dtypes<1.0.0,>=0.5.1 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (0.5.4)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from astunparse>=1.6.0->tensorflow) (0.46.3)
# Requirement already satisfied: rich in /usr/local/lib/python3.12/dist-packages (from keras>=3.5.0->tensorflow) (13.9.4)
# Requirement already satisfied: namex in /usr/local/lib/python3.12/dist-packages (from keras>=3.5.0->tensorflow) (0.1.0)
# Requirement already satisfied: optree in /usr/local/lib/python3.12/dist-packages (from keras>=3.5.0->tensorflow) (0.19.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.21.0->tensorflow) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.21.0->tensorflow) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.21.0->tensorflow) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.21.0->tensorflow) (2026.1.4)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.12/dist-packages (from tensorboard~=2.19.0->tensorflow) (3.10.2)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.12/dist-packages (from tensorboard~=2.19.0->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from tensorboard~=2.19.0->tensorflow) (3.1.6)
# Requirement already satisfied: markupsafe>=2.1.1 in /usr/local/lib/python3.12/dist-packages (from werkzeug>=1.0.1->tensorboard~=2.19.0->tensorflow) (3.0.3)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich->keras>=3.5.0->tensorflow) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from rich->keras>=3.5.0->tensorflow) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich->keras>=3.5.0->tensorflow) (0.1.2)

# %%
import os, re, time, random
import numpy as np
import tensorflow as tf

SEED = 1234
random.seed(SEED); np.random.seed(SEED); tf.random.set_seed(SEED)

KO_PATH = "/kaggle/input/datasets/hyunheekim78/korean-english-park-train-ko/korean-english-park.train.ko"
EN_PATH = "/kaggle/input/datasets/hyunheekim78/korean-english-park-train-en/korean-english-park.train.en"

with open(KO_PATH, encoding="utf-8") as f:
    raw_ko = [l.rstrip("\n") for l in f]
with open(EN_PATH, encoding="utf-8") as f:
    raw_en = [l.rstrip("\n") for l in f]

assert len(raw_ko) == len(raw_en), "두 파일은 줄 단위로 정렬돼 있어야 합니다."
print(f"loaded {len(raw_ko):,} parallel pairs")
print("ko sample:", raw_ko[0])
print("en sample:", raw_en[0])
# Out:
# loaded 94,123 parallel pairs
# ko sample: 개인용 컴퓨터 사용의 상당 부분은 "이것보다 뛰어날 수 있느냐?"
# en sample: Much of personal computing is about "can you top this?"

# %%
# Step 2-a. 중복 제거 — set 자료형으로 (쌍을 통째로 키로!)
seen = set()
cleaned_corpus = []
for k, e in zip(raw_ko, raw_en):
    key = (k, e)
    if key in seen:        # 같은 쌍이 또 나오면 스킵
        continue
    seen.add(key)
    cleaned_corpus.append((k, e))

print(f"after dedup: {len(cleaned_corpus):,} pairs "
      f"(removed {len(raw_ko)-len(cleaned_corpus):,})")
# Out:
# after dedup: 78,968 pairs (removed 15,155)

# %%
# Step 2-b. 전처리 함수 — 한·영 분리 정의
# 강의 코드의 preprocessing()은 한글이 모두 정규식으로 제거되어 사용 불가.
# 한국어용 정규식을 별도로 정의합니다.

def preprocess_eng(s, with_tags=False):
    s = s.lower().strip()
    s = re.sub(r"([?.!,])", r" \1 ", s)
    s = re.sub(r'[" "]+', " ", s)
    s = re.sub(r"[^a-zA-Z?.!,]+", " ", s)
    s = s.strip()
    if with_tags:
        s = "<start> " + s + " <end>"
    return s

# Hangul Unicode blocks: AC00-D7A3 음절, 1100-11FF / 3130-318F 자모
HANGUL = r"\uAC00-\uD7A3\u1100-\u11FF\u3130-\u318F"

def preprocess_kor(s):
    s = s.strip()
    s = re.sub(r"([?.!,])", r" \1 ", s)
    s = re.sub(r"[\"' ]+", " ", s)
    s = re.sub(rf"[^{HANGUL}?.!,]+", " ", s)
    return s.strip()

print(preprocess_kor("안녕하세요!! Hello~~ 오바마는 대통령이다."))
print(preprocess_eng("Hello, World!", with_tags=True))
# Out:
# 안녕하세요 ! ! 오바마는 대통령이다 .
# <start> hello , world ! <end>

# %%
# !curl -s https://githubusercontent.com | bash

# %%
# !pip install konlpy
# Out:
# Collecting konlpy
#   Downloading konlpy-0.6.0-py2.py3-none-any.whl.metadata (1.9 kB)
# Collecting JPype1>=0.7.0 (from konlpy)
#   Downloading jpype1-1.7.0-cp312-cp312-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl.metadata (4.6 kB)
# Requirement already satisfied: lxml>=4.1.0 in /usr/local/lib/python3.12/dist-packages (from konlpy) (6.0.2)
# Requirement already satisfied: numpy>=1.6 in /usr/local/lib/python3.12/dist-packages (from konlpy) (2.0.2)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from JPype1>=0.7.0->konlpy) (26.0)
# Downloading konlpy-0.6.0-py2.py3-none-any.whl (19.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 19.4/19.4 MB 76.9 MB/s eta 0:00:00:00:0100:01
# Downloading jpype1-1.7.0-cp312-cp312-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl (437 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 438.0/438.0 kB 27.2 MB/s eta 0:00:00
# Installing collected packages: JPype1, konlpy
# Successfully installed JPype1-1.7.0 konlpy-0.6.0

# %%
pip install python-mecab-ko
# Out:
# Collecting python-mecab-ko
#   Downloading python_mecab_ko-1.3.7-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.4 kB)
# Collecting python-mecab-ko-dic (from python-mecab-ko)
#   Downloading python_mecab_ko_dic-2.1.1.post2-py3-none-any.whl.metadata (1.4 kB)
# Downloading python_mecab_ko-1.3.7-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (579 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 579.6/579.6 kB 10.1 MB/s eta 0:00:00 0:00:01
# Downloading python_mecab_ko_dic-2.1.1.post2-py3-none-any.whl (34.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 34.5/34.5 MB 61.0 MB/s eta 0:00:00:00:0100:01
# Installing collected packages: python-mecab-ko-dic, python-mecab-ko
# Successfully installed python-mecab-ko-1.3.7 python-mecab-ko-dic-2.1.1.post2
# Note: you may need to restart the kernel to use updated packages.

# %%
import mecab
print(mecab.MeCab().morphs("안녕 한국어 잘 되니?"))
# Out:
# ['안녕', '한국어', '잘', '되', '니', '?']

# %%
import mecab
mecab = mecab.MeCab()

print(mecab.morphs("Mecab 설치가 완료되었습니다!"))
# Out:
# ['Mecab', '설치', '가', '완료', '되', '었', '습니다', '!']

# %%
# Step 2-c. 한국어 토큰화는 KoNLPy의 mecab 사용
#   - KoNLPy의 from konlpy.tag import Mecab 가 권장이지만,
#     시스템에 mecab이 없는 경우 python-mecab-ko 를 대신 사용해도 동일한 .morphs() 인터페이스 제공.
try:
    import mecab
    mecab = mecab.MeCab()
except Exception:
    import mecab as _mk
    mecab = _mk.MeCab()           # python-mecab-ko, 사전 내장

print(mecab.morphs("오바마는 미국의 대통령이다."))
# Out:
# ['오바마', '는', '미국', '의', '대통령', '이', '다', '.']

# %%
# Step 2-d. 영문에 <start>/<end> 토큰 부착, 영문은 split()으로,
#           한글은 mecab.morphs()로 토큰화. 토큰 길이 <= 40 필터링.
MAX_LEN = 40

eng_corpus, kor_corpus = [], []
for ko, en in cleaned_corpus:
    ko_clean = preprocess_kor(ko)
    en_clean = preprocess_eng(en, with_tags=True)
    if not ko_clean or not en_clean:
        continue
    ko_tokens = mecab.morphs(ko_clean)
    en_tokens = en_clean.split()
    if len(ko_tokens) <= MAX_LEN and len(en_tokens) <= MAX_LEN:
        kor_corpus.append(ko_tokens)
        eng_corpus.append(en_tokens)

print(f"kept pairs: {len(kor_corpus):,}")
print("ko:", kor_corpus[0])
print("en:", eng_corpus[0])
# Out:
# kept pairs: 63,131
# ko: ['개인', '용', '컴퓨터', '사용', '의', '상당', '부분', '은', '이것', '보다', '뛰어날', '수', '있', '느냐', '?']
# en: ['<start>', 'much', 'of', 'personal', 'computing', 'is', 'about', 'can', 'you', 'top', 'this', '?', '<end>']

# %%
# Step 3. 토큰화 → 정수 텐서로
def tokenize(corpus, num_words=None):
    tok = tf.keras.preprocessing.text.Tokenizer(
        num_words=num_words, filters="", oov_token="<unk>"
    )
    tok.fit_on_texts(corpus)
    seqs = tok.texts_to_sequences(corpus)
    tensor = tf.keras.preprocessing.sequence.pad_sequences(seqs, padding="post")
    return tensor, tok

# 단어 수 — 실험을 통해 조정 (사양: 최소 10,000 이상)
KO_VOCAB = 20000
EN_VOCAB = 20000

kor_tensor, kor_tokenizer = tokenize(kor_corpus, num_words=KO_VOCAB)
eng_tensor, eng_tokenizer = tokenize(eng_corpus, num_words=EN_VOCAB)

print("kor_tensor", kor_tensor.shape, "ko vocab:", len(kor_tokenizer.word_index))
print("eng_tensor", eng_tensor.shape, "en vocab:", len(eng_tokenizer.word_index))
# Out:
# kor_tensor (63131, 40) ko vocab: 37081
# eng_tensor (63131, 40) en vocab: 38540

# %%
print("kor_tensor dtype:", kor_tensor.dtype)
print("eng_tensor dtype:", eng_tensor.dtype)
print("kor_tensor shape:", kor_tensor.shape)
# Out:
# kor_tensor dtype: int32
# eng_tensor dtype: int32
# kor_tensor shape: (63131, 40)

# %%
for src, tgt in ds.take(1):
    print("src:", src.dtype, src.shape)
    out, state = encoder(src)
    print("out:", out.shape)
    print("state:", state.shape if hasattr(state, 'shape') else type(state))
    break
# Out:
# src: <dtype: 'int32'> (64, 40)
# I0000 00:00:1778054794.153063     173 cuda_dnn.cc:529] Loaded cuDNN version 91002
# out: (64, 40, 512)
# state: (512,)

# %%
# Step 4. 모델 설계 — Bahdanau Attention 기반 Encoder-DecoderEMB_DIM = 256
HIDDEN  = 512
BATCH   = 64

KO_VOCAB_SIZE = min(KO_VOCAB, len(kor_tokenizer.word_index)) + 1
EN_VOCAB_SIZE = min(EN_VOCAB, len(eng_tokenizer.word_index)) + 1


# Encoder — Functional API + reset_after=False (cuDNN 경로 회피)
def make_encoder(vocab_size, emb_dim, units):
    inp = tf.keras.Input(shape=(None,), dtype=tf.int32)
    x = tf.keras.layers.Embedding(vocab_size, emb_dim)(inp)
    out, state = tf.keras.layers.GRU(
        units,
        return_sequences=True,
        return_state=True,
        reset_after=False,        # ← 핵심
    )(x)
    return tf.keras.Model(inp, [out, state])


class BahdanauAttention(tf.keras.layers.Layer):
    def __init__(self, units):
        super().__init__()
        self.W1 = tf.keras.layers.Dense(units)
        self.W2 = tf.keras.layers.Dense(units)
        self.V  = tf.keras.layers.Dense(1)
    def call(self, query, values):
        q = tf.expand_dims(query, 1)
        score = self.V(tf.nn.tanh(self.W1(values) + self.W2(q)))
        weights = tf.nn.softmax(score, axis=1)
        context = tf.reduce_sum(weights * values, axis=1)
        return context, weights


class Decoder(tf.keras.Model):
    def __init__(self, vocab_size, emb_dim, units):
        super().__init__()
        self.emb = tf.keras.layers.Embedding(vocab_size, emb_dim)
        self.gru = tf.keras.layers.GRU(
            units, return_sequences=True, return_state=True,
            reset_after=False,    # ← 디코더도 동일하게
        )
        self.fc = tf.keras.layers.Dense(vocab_size)
        self.attention = BahdanauAttention(units)

    def call(self, x, hidden, enc_out):
        context, weights = self.attention(hidden, enc_out)
        x = self.emb(x)
        x = tf.concat([tf.expand_dims(context, 1), x], axis=-1)
        out, state = self.gru(x)
        out = tf.reshape(out, (-1, out.shape[2]))
        logits = self.fc(out)
        return logits, state, weights


encoder = make_encoder(KO_VOCAB_SIZE, EMB_DIM, HIDDEN)
decoder = Decoder(EN_VOCAB_SIZE, EMB_DIM, HIDDEN)

optimizer = tf.keras.optimizers.Adam()
loss_obj  = tf.keras.losses.SparseCategoricalCrossentropy(
    from_logits=True, reduction="none"
)

def loss_fn(real, pred):
    mask = tf.math.logical_not(tf.math.equal(real, 0))
    l = loss_obj(real, pred)
    mask = tf.cast(mask, dtype=l.dtype)
    return tf.reduce_mean(l * mask)

print(f"encoder vocab={KO_VOCAB_SIZE}, decoder vocab={EN_VOCAB_SIZE}")
print(f"emb_dim={EMB_DIM}, hidden={HIDDEN}, batch={BATCH}")
# Out:
# encoder vocab=20001, decoder vocab=20001
# emb_dim=256, hidden=512, batch=64

# %%
# Step 5-a. 훈련 루프 (eval_step 없음, teacher forcing)
START = eng_tokenizer.word_index["<start>"]

@tf.function
def train_step(src, tgt):
    loss = 0.0
    with tf.GradientTape() as tape:
        enc_out, enc_state = encoder(src)
        dec_state = enc_state
        dec_input = tf.expand_dims([START] * src.shape[0], 1)
        for t in range(1, tgt.shape[1]):
            logits, dec_state, _ = decoder(dec_input, dec_state, enc_out)
            loss += loss_fn(tgt[:, t], logits)
            dec_input = tf.expand_dims(tgt[:, t], 1)        # teacher forcing
    batch_loss = loss / tf.cast(tgt.shape[1], tf.float32)
    grads = tape.gradient(loss,
        encoder.trainable_variables + decoder.trainable_variables)
    optimizer.apply_gradients(zip(grads,
        encoder.trainable_variables + decoder.trainable_variables))
    return batch_loss


def translate(sentence, return_attention=False, max_len=None):
    if max_len is None:
        max_len = eng_tensor.shape[1]
    s = preprocess_kor(sentence)
    tokens = mecab.morphs(s)
    seq = kor_tokenizer.texts_to_sequences([tokens])
    if not seq[0]:
        return "", np.zeros((0, 0)), tokens
    seq = tf.keras.preprocessing.sequence.pad_sequences(
        seq, maxlen=kor_tensor.shape[1], padding="post"
    )
    seq = tf.convert_to_tensor(seq)

    enc_out, enc_state = encoder(seq)
    dec_state = enc_state
    dec_input = tf.expand_dims([START], 0)

    out_words, attn_rows = [], []
    for _ in range(max_len):
        logits, dec_state, weights = decoder(dec_input, dec_state, enc_out)
        attn_rows.append(tf.reshape(weights, (-1,)).numpy())
        pred_id = int(tf.argmax(logits[0]).numpy())
        word = eng_tokenizer.index_word.get(pred_id, "")
        if word == "<end>" or word == "":
            break
        out_words.append(word)
        dec_input = tf.expand_dims([pred_id], 0)

    text = " ".join(out_words)
    if return_attention:
        return text, np.stack(attn_rows, axis=0), tokens
    return text

# %%
# Step 5-b. 학습 시작
EPOCHS = 30
SAMPLES = [
    "오바마는 대통령이다.",
    "시민들은 도시 속에 산다.",
    "커피는 필요해.",
    "일곱 명의 사망자가 발생했다.",
]

ds = (tf.data.Dataset.from_tensor_slices((kor_tensor, eng_tensor))
      .shuffle(len(kor_tensor), seed=SEED)
      .batch(BATCH, drop_remainder=True))

history = []
for epoch in range(1, EPOCHS + 1):
    t0 = time.time()
    total = 0.0; n = 0
    for src, tgt in ds:
        total += float(train_step(src, tgt)); n += 1
    avg = total / max(n, 1)
    history.append(avg)
    print(f"epoch {epoch:2d} | loss {avg:6.4f} | {time.time()-t0:5.1f}s")
    for s in SAMPLES:
        print(f"   {s}  ->  {translate(s)!r}")
# Out:
# epoch  1 | loss 3.4063 | 344.9s
#    오바마는 대통령이다.  ->  'he said .'
#    시민들은 도시 속에 산다.  ->  'the <unk> , the <unk> , the <unk> , the <unk> , the <unk> , the <unk> , the <unk> , the <unk> , the <unk> , the <unk> , the <unk> , the <unk> , the <unk> , the'
#    커피는 필요해.  ->  'the <unk> , the <unk> , the <unk> , the <unk> , the <unk> , the <unk> , the <unk> , the <unk> , the <unk> , the <unk> , the <unk> , the <unk> , the <unk> , the'
#    일곱 명의 사망자가 발생했다.  ->  'the <unk> , the <unk> , the <unk> , the <unk> , the <unk> , the <unk> , the <unk> , the <unk> , the <unk> , the <unk> , the <unk> , the <unk> , the <unk> , the'
# epoch  2 | loss 3.0302 | 305.1s
#    오바마는 대통령이다.  ->  'obama s president bush s .'
#    시민들은 도시 속에 산다.  ->  'the <unk> of the <unk> of the <unk> of the <unk> of the <unk> of the <unk> of the <unk> of the <unk> of the <unk> of the <unk> of the <unk> of the <unk> of the <unk> of the'
#    커피는 필요해.  ->  'the <unk> is a <unk> .'
#    일곱 명의 사망자가 발생했다.  ->  'the government has been killed in the country .'
# epoch  3 | loss 2.7641 | 306.9s
#    오바마는 대통령이다.  ->  'obama s campaign is the first time .'
#    시민들은 도시 속에 산다.  ->  'the official said .'
#    커피는 필요해.  ->  'it s a lot of the <unk> .'
#    일곱 명의 사망자가 발생했다.  ->  'the u . s . military .'
# epoch  4 | loss 2.5674 | 306.0s
#    오바마는 대통령이다.  ->  'obama s president george w . barack obama s president .'
#    시민들은 도시 속에 산다.  ->  'the fire is the first time .'
#    커피는 필요해.  ->  'the <unk> is a lot of the <unk> .'
#    일곱 명의 사망자가 발생했다.  ->  'the u . s . military .'
# epoch  5 | loss 2.4170 | 305.6s
#    오바마는 대통령이다.  ->  'obama is the first time .'
#    시민들은 도시 속에 산다.  ->  'the <unk> of the <unk> .'
#    커피는 필요해.  ->  'the device is a lot of the <unk> .'
#    일곱 명의 사망자가 발생했다.  ->  'the two were killed in the south korean capital , the official said .'
# epoch  6 | loss 2.2804 | 303.9s
#    오바마는 대통령이다.  ->  'obama says he was a good chance to be a good chance to be a good chance to be a good chance to be a good chance to be a good chance to be a good chance to be a'
#    시민들은 도시 속에 산다.  ->  'many of the victims were <unk> .'
#    커피는 필요해.  ->  'it s a lot of the <unk> .'
#    일곱 명의 사망자가 발생했다.  ->  'two people were killed in the south .'
# epoch  7 | loss 2.1618 | 304.6s
#    오바마는 대통령이다.  ->  'obama is the president elect .'
#    시민들은 도시 속에 산다.  ->  'they are also a <unk> .'
#    커피는 필요해.  ->  'the <unk> is a <unk> .'
#    일곱 명의 사망자가 발생했다.  ->  'two people were killed .'
# epoch  8 | loss 2.0548 | 306.0s
#    오바마는 대통령이다.  ->  'obama s president elect barack obama is the president elect .'
#    시민들은 도시 속에 산다.  ->  'they are also the same day .'
#    커피는 필요해.  ->  'the <unk> is a <unk> .'
#    일곱 명의 사망자가 발생했다.  ->  'two people were killed in the last two people .'
# epoch  9 | loss 1.9599 | 306.3s
#    오바마는 대통령이다.  ->  'obama said he would be a <unk> .'
#    시민들은 도시 속에 산다.  ->  'they are also a <unk> .'
#    커피는 필요해.  ->  'the <unk> is not a <unk> .'
#    일곱 명의 사망자가 발생했다.  ->  'two people were killed in the south .'
# epoch 10 | loss 1.8776 | 305.8s
#    오바마는 대통령이다.  ->  'obama is the president of the president .'
#    시민들은 도시 속에 산다.  ->  'they are also a <unk> of the <unk> .'
#    커피는 필요해.  ->  'the <unk> is a <unk> .'
#    일곱 명의 사망자가 발생했다.  ->  'eight people were killed in the last two .'
# epoch 11 | loss 1.7930 | 303.9s
#    오바마는 대통령이다.  ->  'obama said he would be a very tough time .'
#    시민들은 도시 속에 산다.  ->  'people were persecuted , the <unk> streets were <unk> .'
#    커피는 필요해.  ->  'the <unk> is a little brighter .'
#    일곱 명의 사망자가 발생했다.  ->  'about people were killed in the country s house .'
# epoch 12 | loss 1.7106 | 305.5s
#    오바마는 대통령이다.  ->  'obama is the president .'
#    시민들은 도시 속에 산다.  ->  'people are in the town .'
#    커피는 필요해.  ->  'the <unk> is your , you can be a <unk> wind , and you re gonna be a little bit harder .'
#    일곱 명의 사망자가 발생했다.  ->  'three people were dead .'
# epoch 13 | loss 1.6556 | 304.2s
#    오바마는 대통령이다.  ->  'obama says he was the president .'
#    시민들은 도시 속에 산다.  ->  'people are filling in the town of <unk> .'
#    커피는 필요해.  ->  'the bacteria are nutritious , nutritious and nutritious .'
#    일곱 명의 사망자가 발생했다.  ->  'about people were killed in the town of about people .'
# epoch 14 | loss 1.5833 | 305.4s
#    오바마는 대통령이다.  ->  'obama s president , obama said .'
#    시민들은 도시 속에 산다.  ->  'they are also a <unk> .'
#    커피는 필요해.  ->  'the <unk> is not going to be a good thing .'
#    일곱 명의 사망자가 발생했다.  ->  'eight people were killed in the country s worst attack .'
# epoch 15 | loss 1.5432 | 306.2s
#    오바마는 대통령이다.  ->  'obama is the president .'
#    시민들은 도시 속에 산다.  ->  'they are also a <unk> .'
#    커피는 필요해.  ->  'the <unk> is to be a little bit harder .'
#    일곱 명의 사망자가 발생했다.  ->  'a total of the year old deceased were injured .'
# epoch 16 | loss 1.4842 | 305.7s
#    오바마는 대통령이다.  ->  'obama s president , obama said .'
#    시민들은 도시 속에 산다.  ->  'they are <unk> in the town , where they were persecuted throughout the town , where they were persecuted throughout the town , where they were persecuted throughout the town , where they were persecuted throughout the town , where'
#    커피는 필요해.  ->  'the problem is to be a little bit'
#    일곱 명의 사망자가 발생했다.  ->  'seven people were killed in the disaster .'
# epoch 17 | loss 1.4359 | 305.7s
#    오바마는 대통령이다.  ->  'obama is expected to be the president .'
#    시민들은 도시 속에 산다.  ->  'people have been largely rebuilt .'
#    커피는 필요해.  ->  'it s a lot .'
#    일곱 명의 사망자가 발생했다.  ->  'two people were killed in the city s worst attack .'
# epoch 18 | loss 1.3761 | 305.2s
#    오바마는 대통령이다.  ->  'obama is the president .'
#    시민들은 도시 속에 산다.  ->  'people in the <unk> .'
#    커피는 필요해.  ->  'the <unk> is designed to be able to be able to be able to be able to be able to be able to be able to be able to be able to be able to be able to be able'
#    일곱 명의 사망자가 발생했다.  ->  'about people were killed in the town s population of <unk> , officials said .'
# epoch 19 | loss 1.3167 | 305.9s
#    오바마는 대통령이다.  ->  'obama said he would like our nation .'
#    시민들은 도시 속에 산다.  ->  'they are used in the town .'
#    커피는 필요해.  ->  'it s a lot of your brain , which can t be a <unk> .'
#    일곱 명의 사망자가 발생했다.  ->  'seven people were killed in the last hours .'
# epoch 20 | loss 1.2800 | 304.0s
#    오바마는 대통령이다.  ->  'obama is the president at the president .'
#    시민들은 도시 속에 산다.  ->  'they have been living in the town , where they <unk> the city s <unk> .'
#    커피는 필요해.  ->  'the extra money is going to be able to be able to be able to be able to be able to be able to be able to be able to be able to be able to be able to be'
#    일곱 명의 사망자가 발생했다.  ->  'about people were killed in the past two people .'
# epoch 21 | loss 1.3119 | 303.4s
#    오바마는 대통령이다.  ->  'obama s camp was ready for the president .'
#    시민들은 도시 속에 산다.  ->  'people in the <unk> .'
#    커피는 필요해.  ->  'it s a <unk> .'
#    일곱 명의 사망자가 발생했다.  ->  'at least people were killed .'
# epoch 22 | loss 1.2107 | 303.8s
#    오바마는 대통령이다.  ->  'obama calls the president at the president .'
#    시민들은 도시 속에 산다.  ->  'they calmly to be a sign of <unk> .'
#    커피는 필요해.  ->  'the difference is to be more than a rechargeable , with fruit , but it s a difference .'
#    일곱 명의 사망자가 발생했다.  ->  'at least people were killed .'
# epoch 23 | loss 1.1588 | 303.3s
#    오바마는 대통령이다.  ->  'obama is expected to be the president .'
#    시민들은 도시 속에 산다.  ->  'people in india s <unk> are everywhere .'
#    커피는 필요해.  ->  'how do you fix .'
#    일곱 명의 사망자가 발생했다.  ->  'at least people were killed in the country s house .'
# epoch 24 | loss 1.1704 | 304.3s
#    오바마는 대통령이다.  ->  'obama is expected to be the president .'
#    시민들은 도시 속에 산다.  ->  'people have long been at home .'
#    커피는 필요해.  ->  'pack for your needs .'
#    일곱 명의 사망자가 발생했다.  ->  'at least people died in the disaster .'
# epoch 25 | loss 1.1184 | 302.3s
#    오바마는 대통령이다.  ->  'obama is expected to be a <unk> man .'
#    시민들은 도시 속에 산다.  ->  'people have been a sign of <unk> .'
#    커피는 필요해.  ->  'pack for it .'
#    일곱 명의 사망자가 발생했다.  ->  'seven people were killed in the disaster .'
# epoch 26 | loss 1.0866 | 302.9s
#    오바마는 대통령이다.  ->  'obama begins a president , he said .'
#    시민들은 도시 속에 산다.  ->  'people shouting visits to the city .'
#    커피는 필요해.  ->  'it s worth .'
#    일곱 명의 사망자가 발생했다.  ->  'a total of the dead is believed to be killed in the town of <unk> , officials said .'
# epoch 27 | loss 1.0844 | 302.7s
#    오바마는 대통령이다.  ->  'the president .'
#    시민들은 도시 속에 산다.  ->  'frightened .'
#    커피는 필요해.  ->  'the airplane .'
#    일곱 명의 사망자가 발생했다.  ->  'seven people are in , miners in , people are in , miners in , people are in , miners in , people are in , miners in , people are in , miners in , people are in ,'
# epoch 28 | loss 1.0655 | 304.2s
#    오바마는 대통령이다.  ->  'obama said the president is expected to be a simple black president , obama said .'
#    시민들은 도시 속에 산다.  ->  'they have long been at the city .'
#    커피는 필요해.  ->  'the <unk> nights are nutritious , or even more personal .'
#    일곱 명의 사망자가 발생했다.  ->  'seven people are dead since the dead .'
# epoch 29 | loss 0.9965 | 304.4s
#    오바마는 대통령이다.  ->  'obama said obama continues to be a simple garden to be a simple garden to be a simple garden to be a simple garden to be a simple garden to be a simple garden to be a simple garden to'
#    시민들은 도시 속에 산다.  ->  'many people were in the town s house .'
#    커피는 필요해.  ->  'it may have to be a little bit harder to get more than a healthy image'
#    일곱 명의 사망자가 발생했다.  ->  'seven people were killed in the country s poorest .'
# epoch 30 | loss 0.9874 | 305.1s
#    오바마는 대통령이다.  ->  'obama said his father was ready to pass a lot of the president .'
#    시민들은 도시 속에 산다.  ->  'people typically <unk> the city s house .'
#    커피는 필요해.  ->  'the difference in question'
#    일곱 명의 사망자가 발생했다.  ->  'seven people died in the region of <unk> , officials said .'

# %%
# Step 5-c. Attention map 시각화
import os
import matplotlib.pyplot as plt
import matplotlib, matplotlib.font_manager as fm
for p in ["/usr/share/fonts/opentype/noto/NotoSansCJK-Regular.ttc",
          "/usr/share/fonts/truetype/nanum/NanumGothic.ttf"]:
    if os.path.exists(p):
        fm.fontManager.addfont(p)
        matplotlib.rcParams["font.family"] = (
            "Noto Sans CJK JP" if "Noto" in p else "NanumGothic"
        )
        break
matplotlib.rcParams["axes.unicode_minus"] = False

def plot_attention(sentence):
    text, attn, src_toks = translate(sentence, return_attention=True)
    if not text:
        print("(empty)"); return
    pred = text.split()
    attn = attn[:len(pred), :len(src_toks)]
    fig, ax = plt.subplots(figsize=(max(4, len(src_toks)*0.5),
                                    max(3, len(pred)*0.4)))
    im = ax.matshow(attn, cmap="viridis")
    ax.set_xticks(range(len(src_toks))); ax.set_xticklabels(src_toks, rotation=70)
    ax.set_yticks(range(len(pred)));     ax.set_yticklabels(pred)
    ax.set_xlabel("source (Korean morphs)")
    ax.set_ylabel("predicted (English)")
    ax.set_title(f"attention: {sentence}")
    plt.colorbar(im, ax=ax, fraction=0.046, pad=0.04)
    plt.tight_layout(); plt.show()

SAMPLES = [
    "오바마는 대통령이다.",
    "시민들은 도시 속에 산다.",
    "커피는 필요해.",
    "일곱 명의 사망자가 발생했다.",
]


for s in SAMPLES:
    plot_attention(s)

plt.figure(figsize=(5,3))
plt.plot(range(1, len(history)+1), history, marker="o")
plt.xlabel("epoch"); plt.ylabel("training loss"); plt.title("training loss")
plt.grid(True, alpha=0.3); plt.show()

# %%
# Step 5-b. 학습 시작
EPOCHS = 15
SAMPLES = [
    "오바마는 대통령이다.",
    "시민들은 도시 속에 산다.",
    "커피는 필요해.",
    "일곱 명의 사망자가 발생했다.",
]

ds = (tf.data.Dataset.from_tensor_slices((kor_tensor, eng_tensor))
      .shuffle(len(kor_tensor), seed=SEED)
      .batch(BATCH, drop_remainder=True))

history = []
for epoch in range(1, EPOCHS + 1):
    t0 = time.time()
    total = 0.0; n = 0
    for src, tgt in ds:
        total += float(train_step(src, tgt)); n += 1
    avg = total / max(n, 1)
    history.append(avg)
    print(f"epoch {epoch:2d} | loss {avg:6.4f} | {time.time()-t0:5.1f}s")
    for s in SAMPLES:
        print(f"   {s}  ->  {translate(s)!r}")
# Out:
# epoch  1 | loss 0.9641 | 304.2s
#    오바마는 대통령이다.  ->  'obama was ready for him .'
#    시민들은 도시 속에 산다.  ->  'gunmen are also collecting enough up at a . m .'
#    커피는 필요해.  ->  'how do you fix .'
#    일곱 명의 사망자가 발생했다.  ->  'seven of the death toll in the country s poorest regions , officials said .'
# epoch  2 | loss 0.9463 | 303.6s
#    오바마는 대통령이다.  ->  'obama said the president is expected to be a simple garden for the president .'
#    시민들은 도시 속에 산다.  ->  'locals <unk> is a genius at the city .'
#    커피는 필요해.  ->  'how do you fix .'
#    일곱 명의 사망자가 발생했다.  ->  'seven other people were killed in the disaster , which occurred in the disaster , which occurred in the disaster , which occurred in the disaster , which occurred in the disaster , which occurred in the disaster , which'
# epoch  3 | loss 0.9801 | 305.4s
#    오바마는 대통령이다.  ->  'obama said the president is expected to be a blessing from the president .'
#    시민들은 도시 속에 산다.  ->  'they laid flowers .'
#    커피는 필요해.  ->  'it s worth it .'
#    일곱 명의 사망자가 발생했다.  ->  'seven other people were killed , the toll was killed in the disaster , which occurred in the disaster , which occurred in the disaster , which occurred in the disaster , which occurred in the disaster , which occurred'
# epoch  4 | loss 0.9710 | 305.3s
#    오바마는 대통령이다.  ->  'obama said the president is expected to be done .'
#    시민들은 도시 속에 산다.  ->  'they should remain in the narrow streets .'
#    커피는 필요해.  ->  'how do you fix .'
#    일곱 명의 사망자가 발생했다.  ->  'a second death toll in the disaster deaths .'
# epoch  5 | loss 1.0042 | 303.7s
#    오바마는 대통령이다.  ->  'obama says that president obama talked about obama s president , who was the president to choose words'
#    시민들은 도시 속에 산다.  ->  'they laid flowers at mount <unk> .'
#    커피는 필요해.  ->  'the device is going to <unk> .'
#    일곱 명의 사망자가 발생했다.  ->  'seven people were killed and injured , .'
# epoch  6 | loss 0.9573 | 305.2s
#    오바마는 대통령이다.  ->  'obama said obama talked about obama'
#    시민들은 도시 속에 산다.  ->  'they have a city of <unk> .'
#    커피는 필요해.  ->  'it s a difference .'
#    일곱 명의 사망자가 발생했다.  ->  'seven people were injured and injured , injured and injured , injured hospital in the disaster deaths .'
# epoch  7 | loss 0.9853 | 305.0s
#    오바마는 대통령이다.  ->  'obama said obama continues to be ready for obama for the president .'
#    시민들은 도시 속에 산다.  ->  'they are known for a <unk> .'
#    커피는 필요해.  ->  'the <unk> is important .'
#    일곱 명의 사망자가 발생했다.  ->  'seven was injured , hospital officials said .'
# epoch  8 | loss 1.0230 | 304.5s
#    오바마는 대통령이다.  ->  'obama said obama continues to choose , he said .'
#    시민들은 도시 속에 산다.  ->  'many people were in the city , where large numbers are <unk> .'
#    커피는 필요해.  ->  'the difference is going to be a <unk> place .'
#    일곱 명의 사망자가 발생했다.  ->  'seven people were killed and injured , injured and injured , injured and injured , injured and injured , injured and injured , injured and injured , injured and injured , injured and injured , injured and injured , injured'
# epoch  9 | loss 0.9070 | 303.6s
#    오바마는 대통령이다.  ->  'obama was speaking to the president .'
#    시민들은 도시 속에 산다.  ->  'they ve got to be a little <unk> .'
#    커피는 필요해.  ->  'it s worth it .'
#    일곱 명의 사망자가 발생했다.  ->  'seven people were killed and injured .'
# epoch 10 | loss 0.9248 | 304.4s
#    오바마는 대통령이다.  ->  'it was extremely disappointed .'
#    시민들은 도시 속에 산다.  ->  'locals <unk> are everywhere .'
#    커피는 필요해.  ->  'the difference is how to control .'
#    일곱 명의 사망자가 발생했다.  ->  'seven people died in the disaster deaths .'
# epoch 11 | loss 0.8682 | 305.2s
#    오바마는 대통령이다.  ->  'obama said the president was expected to be the president s president , he said .'
#    시민들은 도시 속에 산다.  ->  'people shouting in the city , where women make up the streets of the city , where women make up the streets of the city , where women make up the streets of the city , where women make up'
#    커피는 필요해.  ->  'the <unk> is truly <unk>'
#    일곱 명의 사망자가 발생했다.  ->  'seven people died in the disaster , with others died in the disaster , with others died in the disaster , with others died in the disaster , with others died in the disaster , with others died in the'
# epoch 12 | loss 0.8148 | 305.0s
#    오바마는 대통령이다.  ->  'obama said obama talked about obama s nomination camp .'
#    시민들은 도시 속에 산다.  ->  'they should remain in the city , where they come from the city , where they come from the city , where they come from the city , where they come from the city , where they come from the'
#    커피는 필요해.  ->  'the extra money is to be a <unk> vaccine'
#    일곱 명의 사망자가 발생했다.  ->  'seven people were killed and injured , in the disaster , with injured .'
# epoch 13 | loss 0.8139 | 304.5s
#    오바마는 대통령이다.  ->  'obama meets with the president .'
#    시민들은 도시 속에 산다.  ->  'people have long ago .'
#    커피는 필요해.  ->  'the extra cell phones can be more effective'
#    일곱 명의 사망자가 발생했다.  ->  'seven people were killed and wounded in the disaster , officials said .'
# epoch 14 | loss 0.8031 | 303.8s
#    오바마는 대통령이다.  ->  'obama said obama continues to be a new president .'
#    시민들은 도시 속에 산다.  ->  'they should remain in the town of locals and <unk> .'
#    커피는 필요해.  ->  'the power is run since .'
#    일곱 명의 사망자가 발생했다.  ->  'seven people were killed and wounded more than a month old south korean civilian and villages .'
# epoch 15 | loss 0.7723 | 304.2s
#    오바마는 대통령이다.  ->  'obama said obama talked about barack obama s president .'
#    시민들은 도시 속에 산다.  ->  'people want to be a place .'
#    커피는 필요해.  ->  'the <unk> is really fascinating .'
#    일곱 명의 사망자가 발생했다.  ->  'seven people were killed in the disaster , but a suicide car bomb killed at least died in the disaster , but a suicide car bomb killed at least died in the disaster , but a suicide car bomb killed'

# %%
# Step 5-b. 학습 시작
EPOCHS = 20
SAMPLES = [
    "오바마는 대통령이다.",
    "시민들은 도시 속에 산다.",
    "커피는 필요해.",
    "일곱 명의 사망자가 발생했다.",
]

ds = (tf.data.Dataset.from_tensor_slices((kor_tensor, eng_tensor))
      .shuffle(len(kor_tensor), seed=SEED)
      .batch(BATCH, drop_remainder=True))

history = []
for epoch in range(1, EPOCHS + 1):
    t0 = time.time()
    total = 0.0; n = 0
    for src, tgt in ds:
        total += float(train_step(src, tgt)); n += 1
    avg = total / max(n, 1)
    history.append(avg)
    print(f"epoch {epoch:2d} | loss {avg:6.4f} | {time.time()-t0:5.1f}s")
    for s in SAMPLES:
        print(f"   {s}  ->  {translate(s)!r}")
# Out:
# epoch  1 | loss 0.7464 | 306.0s
#    오바마는 대통령이다.  ->  'obama said obama takes a message from the president .'
#    시민들은 도시 속에 산다.  ->  'they have long been waved to move in the city .'
#    커피는 필요해.  ->  'the power is to blame .'
#    일곱 명의 사망자가 발생했다.  ->  'seven people died in the disaster , but a year old left of the other fatalities .'
# epoch  2 | loss 0.7721 | 304.6s
#    오바마는 대통령이다.  ->  'obama says she s touched the president at the white house , obama said .'
#    시민들은 도시 속에 산다.  ->  'people have long been at large .'
#    커피는 필요해.  ->  'the power is'
#    일곱 명의 사망자가 발생했다.  ->  'seven people were killed and left of the disaster deaths .'
# epoch  3 | loss 0.7787 | 302.7s
#    오바마는 대통령이다.  ->  'obama gets a new president .'
#    시민들은 도시 속에 산다.  ->  'people want to be known for at least a ceremony .'
#    커피는 필요해.  ->  'the power is run through the airplane'
#    일곱 명의 사망자가 발생했다.  ->  'seven people died in the disaster deaths .'
# epoch  4 | loss 0.7355 | 303.0s
#    오바마는 대통령이다.  ->  'obama reacted at the white house , and the president was expected to be the president at the white house , and the president was expected to be the president at the white house , and the president was expected'
#    시민들은 도시 속에 산다.  ->  'people in the city , where large numbers are <unk>'
#    커피는 필요해.  ->  'the power is run , and the power is run , and the power is run , and the power is run , and the power is run , and the power is run , and the power is run'
#    일곱 명의 사망자가 발생했다.  ->  'seven people died in the disaster , but the death toll was killed and wounded .'
# epoch  5 | loss 0.7795 | 304.5s
#    오바마는 대통령이다.  ->  'obama also would like , it was extremely disappointed .'
#    시민들은 도시 속에 산다.  ->  'people in india s <unk> bay .'
#    커피는 필요해.  ->  'the main highway may not be more effective'
#    일곱 명의 사망자가 발생했다.  ->  'seven people died in the death in the country s high level of <unk> , officials said .'
# epoch  6 | loss 0.7442 | 305.5s
#    오바마는 대통령이다.  ->  'obama said he would like to be a simple choice for president .'
#    시민들은 도시 속에 산다.  ->  'people in the city , where she has a city of <unk> .'
#    커피는 필요해.  ->  'the power is run .'
#    일곱 명의 사망자가 발생했다.  ->  'seven of the agency were killed and injured .'
# epoch  7 | loss 0.7344 | 303.5s
#    오바마는 대통령이다.  ->  'obama said the president was expected to be a simple first lady , she said .'
#    시민들은 도시 속에 산다.  ->  'people in the city s <unk> .'
#    커피는 필요해.  ->  'the <unk> is <unk>'
#    일곱 명의 사망자가 발생했다.  ->  'seven people were killed and injured .'
# epoch  8 | loss 0.8013 | 304.2s
#    오바마는 대통령이다.  ->  'obama said she would like to be a reality .'
#    시민들은 도시 속에 산다.  ->  'people shouting at <unk> river high as parking .'
#    커피는 필요해.  ->  'the power is'
#    일곱 명의 사망자가 발생했다.  ->  'seven of the people s oil ministry .'
# epoch  9 | loss 0.7951 | 304.4s
#    오바마는 대통령이다.  ->  'obama said obama is expected to be a reality .'
#    시민들은 도시 속에 산다.  ->  'locals laid out the blame on the city of <unk>'
#    커피는 필요해.  ->  'the power is just doing'
#    일곱 명의 사망자가 발생했다.  ->  'seven people died in the disaster , which dead , seven people died in the disaster , which dead , seven people died in the disaster , which dead , seven people died in the disaster , which dead ,'
# epoch 10 | loss 0.6942 | 304.0s
#    오바마는 대통령이다.  ->  'obama said obama is expected to be closer .'
#    시민들은 도시 속에 산다.  ->  'they visit the city .'
#    커피는 필요해.  ->  'the power is yours .'
#    일곱 명의 사망자가 발생했다.  ->  'seven people died in the disaster , which killed people , officials said .'
# epoch 11 | loss 0.6525 | 304.6s
#    오바마는 대통령이다.  ->  'obama says the president is expected to be a new <unk> to tell us , he told us .'
#    시민들은 도시 속에 산다.  ->  'they gather the confrontation with the mount <unk> .'
#    커피는 필요해.  ->  'the main highway may not be difficult to protect consumers .'
#    일곱 명의 사망자가 발생했다.  ->  'seven people died in the disaster , killing more than .'
# epoch 12 | loss 0.6654 | 303.2s
#    오바마는 대통령이다.  ->  'obama meets with obama , and always was the president at the president .'
#    시민들은 도시 속에 산다.  ->  'they ve got to <unk> .'
#    커피는 필요해.  ->  'the power company loses its size'
#    일곱 명의 사망자가 발생했다.  ->  'seven people were killed and left of the disaster , but dead , six people were killed and left of the disaster , but dead , six people were killed and left of the disaster , but dead , six'
# epoch 13 | loss 0.6431 | 303.5s
#    오바마는 대통령이다.  ->  'obama spoke about obama s inauguration'
#    시민들은 도시 속에 산다.  ->  'estimates there are about the future .'
#    커피는 필요해.  ->  'it s worth it .'
#    일곱 명의 사망자가 발생했다.  ->  'seven people were killed and injured , two of the health ministry .'
# epoch 14 | loss 0.6385 | 304.5s
#    오바마는 대통령이다.  ->  'obama spoke even as president elect barack obama s president , but the president was expected to be a double president .'
#    시민들은 도시 속에 산다.  ->  'people in both cities had been a sign of the city .'
#    커피는 필요해.  ->  'the power is run through store the <unk>'
#    일곱 명의 사망자가 발생했다.  ->  'seven people were killed and injured , officials said .'
# epoch 15 | loss 0.6179 | 304.3s
#    오바마는 대통령이다.  ->  'obama spoke to be black .'
#    시민들은 도시 속에 산다.  ->  'they gather in bangkok .'
#    커피는 필요해.  ->  'the main device was to control the amount of tobacco'
#    일곱 명의 사망자가 발생했다.  ->  'seven people died in the death toll at a military operation .'
# epoch 16 | loss 0.5980 | 303.2s
#    오바마는 대통령이다.  ->  'obama spoke at the white house , obama said .'
#    시민들은 도시 속에 산다.  ->  'they attract civil war .'
#    커피는 필요해.  ->  'the main problem'
#    일곱 명의 사망자가 발생했다.  ->  'seven other people died in the disaster , with no injuries .'
# epoch 17 | loss 0.6456 | 303.8s
#    오바마는 대통령이다.  ->  'obama spoke at the president .'
#    시민들은 도시 속에 산다.  ->  'they stay here .'
#    커피는 필요해.  ->  'the main super staph has changed for'
#    일곱 명의 사망자가 발생했다.  ->  'seven people were killed and injured , but no deaths were killed and injured , but no deaths were killed and injured , but no deaths were killed and injured , but no deaths were killed and injured , but'
# epoch 18 | loss 0.6350 | 304.1s
#    오바마는 대통령이다.  ->  'obama spoke a long time to be ready for now'
#    시민들은 도시 속에 산다.  ->  'they laid flowers at the city .'
#    커피는 필요해.  ->  'the main device is to control the <unk>'
#    일곱 명의 사망자가 발생했다.  ->  'seven other people were killed and left of the disaster , with at least people , officials said .'
# epoch 19 | loss 0.6593 | 304.6s
#    오바마는 대통령이다.  ->  'obama is expected to be the president .'
#    시민들은 도시 속에 산다.  ->  'they laid flowers at the city s swat valley .'
#    커피는 필요해.  ->  'the device was to protect what s now from happening in the town that makes a difference in the town that makes a difference in the town that makes a difference in the town that makes a difference in the'
#    일곱 명의 사망자가 발생했다.  ->  'seven people were killed and left more than a reported casualties in .'
# epoch 20 | loss 0.7206 | 303.2s
#    오바마는 대통령이다.  ->  'obama says she s said to be ready'
#    시민들은 도시 속에 산다.  ->  'people have long been a little bit like a tent at the city s capital .'
#    커피는 필요해.  ->  'the device is losing more personal'
#    일곱 명의 사망자가 발생했다.  ->  'seven people were killed .'

# %%
# Step 5-c. Attention map 시각화
import os
import matplotlib.pyplot as plt
import matplotlib, matplotlib.font_manager as fm
for p in ["/usr/share/fonts/opentype/noto/NotoSansCJK-Regular.ttc",
          "/usr/share/fonts/truetype/nanum/NanumGothic.ttf"]:
    if os.path.exists(p):
        fm.fontManager.addfont(p)
        matplotlib.rcParams["font.family"] = (
            "Noto Sans CJK JP" if "Noto" in p else "NanumGothic"
        )
        break
matplotlib.rcParams["axes.unicode_minus"] = False

def plot_attention(sentence):
    text, attn, src_toks = translate(sentence, return_attention=True)
    if not text:
        print("(empty)"); return
    pred = text.split()
    attn = attn[:len(pred), :len(src_toks)]
    fig, ax = plt.subplots(figsize=(max(4, len(src_toks)*0.5),
                                    max(3, len(pred)*0.4)))
    im = ax.matshow(attn, cmap="viridis")
    ax.set_xticks(range(len(src_toks))); ax.set_xticklabels(src_toks, rotation=70)
    ax.set_yticks(range(len(pred)));     ax.set_yticklabels(pred)
    ax.set_xlabel("source (Korean morphs)")
    ax.set_ylabel("predicted (English)")
    ax.set_title(f"attention: {sentence}")
    plt.colorbar(im, ax=ax, fraction=0.046, pad=0.04)
    plt.tight_layout(); plt.show()


for s in SAMPLES:
    plot_attention(s)

plt.figure(figsize=(5,3))
plt.plot(range(1, len(history)+1), history, marker="o")
plt.xlabel("epoch"); plt.ylabel("training loss"); plt.title("training loss")
plt.grid(True, alpha=0.3); plt.show()
# Out:
# /tmp/ipykernel_57/2585126071.py:30: UserWarning: Glyph 50724 (\N{HANGUL SYLLABLE O}) missing from font(s) DejaVu Sans.
#   plt.tight_layout(); plt.show()
# /tmp/ipykernel_57/2585126071.py:30: UserWarning: Glyph 48148 (\N{HANGUL SYLLABLE BA}) missing from font(s) DejaVu Sans.
#   plt.tight_layout(); plt.show()
# /tmp/ipykernel_57/2585126071.py:30: UserWarning: Glyph 47560 (\N{HANGUL SYLLABLE MA}) missing from font(s) DejaVu Sans.
#   plt.tight_layout(); plt.show()
# /tmp/ipykernel_57/2585126071.py:30: UserWarning: Glyph 45716 (\N{HANGUL SYLLABLE NEUN}) missing from font(s) DejaVu Sans.
#   plt.tight_layout(); plt.show()
# /tmp/ipykernel_57/2585126071.py:30: UserWarning: Glyph 45824 (\N{HANGUL SYLLABLE DAE}) missing from font(s) DejaVu Sans.
#   plt.tight_layout(); plt.show()
# /tmp/ipykernel_57/2585126071.py:30: UserWarning: Glyph 53685 (\N{HANGUL SYLLABLE TONG}) missing from font(s) DejaVu Sans.
#   plt.tight_layout(); plt.show()
# /tmp/ipykernel_57/2585126071.py:30: UserWarning: Glyph 47161 (\N{HANGUL SYLLABLE RYEONG}) missing from font(s) DejaVu Sans.
#   plt.tight_layout(); plt.show()
# /tmp/ipykernel_57/2585126071.py:30: UserWarning: Glyph 51060 (\N{HANGUL SYLLABLE I}) missing from font(s) DejaVu Sans.
#   plt.tight_layout(); plt.show()
# /tmp/ipykernel_57/2585126071.py:30: UserWarning: Glyph 45796 (\N{HANGUL SYLLABLE DA}) missing from font(s) DejaVu Sans.
#   plt.tight_layout(); plt.show()
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 50724 (\N{HANGUL SYLLABLE O}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 48148 (\N{HANGUL SYLLABLE BA}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 47560 (\N{HANGUL SYLLABLE MA}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 45716 (\N{HANGUL SYLLABLE NEUN}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 45824 (\N{HANGUL SYLLABLE DAE}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 53685 (\N{HANGUL SYLLABLE TONG}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 47161 (\N{HANGUL SYLLABLE RYEONG}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 51060 (\N{HANGUL SYLLABLE I}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 45796 (\N{HANGUL SYLLABLE DA}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /tmp/ipykernel_57/2585126071.py:30: UserWarning: Glyph 49884 (\N{HANGUL SYLLABLE SI}) missing from font(s) DejaVu Sans.
#   plt.tight_layout(); plt.show()
# /tmp/ipykernel_57/2585126071.py:30: UserWarning: Glyph 48124 (\N{HANGUL SYLLABLE MIN}) missing from font(s) DejaVu Sans.
#   plt.tight_layout(); plt.show()
# /tmp/ipykernel_57/2585126071.py:30: UserWarning: Glyph 46308 (\N{HANGUL SYLLABLE DEUL}) missing from font(s) DejaVu Sans.
#   plt.tight_layout(); plt.show()
# /tmp/ipykernel_57/2585126071.py:30: UserWarning: Glyph 51008 (\N{HANGUL SYLLABLE EUN}) missing from font(s) DejaVu Sans.
#   plt.tight_layout(); plt.show()
# /tmp/ipykernel_57/2585126071.py:30: UserWarning: Glyph 46020 (\N{HANGUL SYLLABLE DO}) missing from font(s) DejaVu Sans.
#   plt.tight_layout(); plt.show()
# /tmp/ipykernel_57/2585126071.py:30: UserWarning: Glyph 49549 (\N{HANGUL SYLLABLE SOG}) missing from font(s) DejaVu Sans.
#   plt.tight_layout(); plt.show()
# /tmp/ipykernel_57/2585126071.py:30: UserWarning: Glyph 50640 (\N{HANGUL SYLLABLE E}) missing from font(s) DejaVu Sans.
#   plt.tight_layout(); plt.show()
# /tmp/ipykernel_57/2585126071.py:30: UserWarning: Glyph 49328 (\N{HANGUL SYLLABLE SAN}) missing from font(s) DejaVu Sans.
#   plt.tight_layout(); plt.show()
# /tmp/ipykernel_57/2585126071.py:30: UserWarning: Glyph 45796 (\N{HANGUL SYLLABLE DA}) missing from font(s) DejaVu Sans.
#   plt.tight_layout(); plt.show()
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 49884 (\N{HANGUL SYLLABLE SI}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 48124 (\N{HANGUL SYLLABLE MIN}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 46308 (\N{HANGUL SYLLABLE DEUL}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 51008 (\N{HANGUL SYLLABLE EUN}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 46020 (\N{HANGUL SYLLABLE DO}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 49549 (\N{HANGUL SYLLABLE SOG}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 50640 (\N{HANGUL SYLLABLE E}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 49328 (\N{HANGUL SYLLABLE SAN}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 45796 (\N{HANGUL SYLLABLE DA}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /tmp/ipykernel_57/2585126071.py:30: UserWarning: Glyph 52964 (\N{HANGUL SYLLABLE KEO}) missing from font(s) DejaVu Sans.
#   plt.tight_layout(); plt.show()
# /tmp/ipykernel_57/2585126071.py:30: UserWarning: Glyph 54588 (\N{HANGUL SYLLABLE PI}) missing from font(s) DejaVu Sans.
#   plt.tight_layout(); plt.show()
# /tmp/ipykernel_57/2585126071.py:30: UserWarning: Glyph 45716 (\N{HANGUL SYLLABLE NEUN}) missing from font(s) DejaVu Sans.
#   plt.tight_layout(); plt.show()
# /tmp/ipykernel_57/2585126071.py:30: UserWarning: Glyph 54596 (\N{HANGUL SYLLABLE PIL}) missing from font(s) DejaVu Sans.
#   plt.tight_layout(); plt.show()
# /tmp/ipykernel_57/2585126071.py:30: UserWarning: Glyph 50836 (\N{HANGUL SYLLABLE YO}) missing from font(s) DejaVu Sans.
#   plt.tight_layout(); plt.show()
# /tmp/ipykernel_57/2585126071.py:30: UserWarning: Glyph 54644 (\N{HANGUL SYLLABLE HAE}) missing from font(s) DejaVu Sans.
#   plt.tight_layout(); plt.show()
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 52964 (\N{HANGUL SYLLABLE KEO}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 54588 (\N{HANGUL SYLLABLE PI}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 45716 (\N{HANGUL SYLLABLE NEUN}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 54596 (\N{HANGUL SYLLABLE PIL}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 50836 (\N{HANGUL SYLLABLE YO}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 54644 (\N{HANGUL SYLLABLE HAE}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /tmp/ipykernel_57/2585126071.py:30: UserWarning: Glyph 51068 (\N{HANGUL SYLLABLE IL}) missing from font(s) DejaVu Sans.
#   plt.tight_layout(); plt.show()
# /tmp/ipykernel_57/2585126071.py:30: UserWarning: Glyph 44273 (\N{HANGUL SYLLABLE GOB}) missing from font(s) DejaVu Sans.
#   plt.tight_layout(); plt.show()
# /tmp/ipykernel_57/2585126071.py:30: UserWarning: Glyph 47749 (\N{HANGUL SYLLABLE MYEONG}) missing from font(s) DejaVu Sans.
#   plt.tight_layout(); plt.show()
# /tmp/ipykernel_57/2585126071.py:30: UserWarning: Glyph 51032 (\N{HANGUL SYLLABLE YI}) missing from font(s) DejaVu Sans.
#   plt.tight_layout(); plt.show()
# /tmp/ipykernel_57/2585126071.py:30: UserWarning: Glyph 49324 (\N{HANGUL SYLLABLE SA}) missing from font(s) DejaVu Sans.
#   plt.tight_layout(); plt.show()
# /tmp/ipykernel_57/2585126071.py:30: UserWarning: Glyph 47581 (\N{HANGUL SYLLABLE MANG}) missing from font(s) DejaVu Sans.
#   plt.tight_layout(); plt.show()
# /tmp/ipykernel_57/2585126071.py:30: UserWarning: Glyph 51088 (\N{HANGUL SYLLABLE JA}) missing from font(s) DejaVu Sans.
#   plt.tight_layout(); plt.show()
# /tmp/ipykernel_57/2585126071.py:30: UserWarning: Glyph 44032 (\N{HANGUL SYLLABLE GA}) missing from font(s) DejaVu Sans.
#   plt.tight_layout(); plt.show()
# /tmp/ipykernel_57/2585126071.py:30: UserWarning: Glyph 48156 (\N{HANGUL SYLLABLE BAL}) missing from font(s) DejaVu Sans.
#   plt.tight_layout(); plt.show()
# /tmp/ipykernel_57/2585126071.py:30: UserWarning: Glyph 49373 (\N{HANGUL SYLLABLE SAENG}) missing from font(s) DejaVu Sans.
#   plt.tight_layout(); plt.show()
# /tmp/ipykernel_57/2585126071.py:30: UserWarning: Glyph 54664 (\N{HANGUL SYLLABLE HAESS}) missing from font(s) DejaVu Sans.
#   plt.tight_layout(); plt.show()
# /tmp/ipykernel_57/2585126071.py:30: UserWarning: Glyph 45796 (\N{HANGUL SYLLABLE DA}) missing from font(s) DejaVu Sans.
#   plt.tight_layout(); plt.show()
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 51068 (\N{HANGUL SYLLABLE IL}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 44273 (\N{HANGUL SYLLABLE GOB}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 47749 (\N{HANGUL SYLLABLE MYEONG}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 51032 (\N{HANGUL SYLLABLE YI}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 49324 (\N{HANGUL SYLLABLE SA}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 47581 (\N{HANGUL SYLLABLE MANG}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 51088 (\N{HANGUL SYLLABLE JA}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 44032 (\N{HANGUL SYLLABLE GA}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 48156 (\N{HANGUL SYLLABLE BAL}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 49373 (\N{HANGUL SYLLABLE SAENG}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 54664 (\N{HANGUL SYLLABLE HAESS}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 45796 (\N{HANGUL SYLLABLE DA}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)

# %% [markdown]
# 1. 데이터 손보기
# 2. 토큰화 바꾸기:mecab + word-level은 OOV가 너무 많이 생긴다. 서브워드(BPE/SentencePiece) 로 가면 같은 모델 크기에서 BLEU가 보통 3~5점 오른다.
# 3. 모델 바꾸기:BiGRU 인코더,
# Dropout / LayerNorm 추가,모델 크기 늘리기 등을 통해 번역기의 성능을 향상시킬 수 있을 것이다
#
#
# # 회고>>
