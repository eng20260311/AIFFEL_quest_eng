# %% [markdown]
# <a href="https://colab.research.google.com/github/eng20260311/AIFFEL_quest_eng/blob/master/Python/Py04/Kiosk2026.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
menu = ['americano', 'latte', 'mocha', 'yuza_tea', 'green_tea', 'choco_latte']
price = [2000, 3000, 3000, 2500, 2500, 3000]
class Kiosk:
    def __init__(self):
        self.menu = menu
        self.price = price
        self.ordered = []

    # 메뉴 출력 메서드
    def menu_print(self):
        for i in range(len(self.menu)):
            print(i+1, self.menu[i], ' : ', self.price[i], '원')

    # 주문 메서드
    def menu_select(self):
        print()  # 줄 바꿈
        n = 0
        while n < 1 or len(menu) < n:
            n = int(input("음료 번호를 입력하세요 : "))  # 음료 번호 입력

            # 메뉴판에 있는 음료 번호일때
            if 1 <= n & n <= len(menu):
                self.price_sum = self.price[n-1]  # 선택 음료의 가격
                 # 문제 2-2의 답을 입력하세요.
                print(self.menu[n-1], ' : ', self.price[n-1] , '원')  # 메뉴
                self.ordered.append(n-1)
             # 메뉴판에 없는 번호일 때
            else:
                print("없는 메뉴입니다. 다시 주문해 주세요.")
                # 음료 온도 물어보기
        t = 0  # 기본값을 넣어주고
        while t != 1 and t != 2:  # 1이나 2를 입력할 때까지 물어보기
            t= int(input("HOT 음료는 1을, ICE 음료는 2를 입력하세요 : "))
            # 문제 2-3. 음료의 온도에 따라 temp 변수를 "HOT" 또는 "ICE"로 지정하세요.
            if t==1:
                self.temp='Hot'
            elif t==2:
                self.temp='Ice'
            else:
                print("1과 2 중 하나를 입력하세요.\n")

        print('주문 음료', self.temp, self.menu[n-1], ' : ', self.price[n-1], '원')  # 온도 속성을 추가한 주문 결과 출력

        question=int(input("추가 주문하시겠습니까? 추가 주문하시려면 0(완료) 또는 1(추가주문)을 입력하십시오.: "))
        if question == 1:
            self.menu_select()
    def info(self):
      totalPrice = 0
      print()
      print("주문하신 내역은")
      for t in self.ordered:
        orderdMenu = self.menu[t]
        orderdPrice = self.price[t]
        totalPrice += orderdPrice
        print(f"{orderdMenu} : {orderdPrice}")
      print(f"총 금액은 {totalPrice}원 입니다")

def pay(self):
    print()
    while self.pay != 1 and self.pay != 2:
       self.pay = int(input("결제방법을 입력하세요. cash는 1번, card는 2번을 입력하세요 : "))
    if self.pay== 1:
        print('직원을 호출하겠습니다')
    elif self.pay== 2:
        print('IC칩 방향에 맞게 카드를 꽂아주세요')
    else :
        print('다시 결제를 시도해 주세요')




Kiosk.pay = pay
a = Kiosk()  # 객체 생성
a.menu_print()  # 메뉴 출력
a.menu_select()  # 주문
a.pay()  # 지불
a.info()
# Out:
# 1 americano  :  2000 원
# 2 latte  :  3000 원
# 3 mocha  :  3000 원
# 4 yuza_tea  :  2500 원
# 5 green_tea  :  2500 원
# 6 choco_latte  :  3000 원
#
# 음료 번호를 입력하세요 : 3
# mocha  :  3000 원
# HOT 음료는 1을, ICE 음료는 2를 입력하세요 : 1
# 주문 음료 Hot mocha  :  3000 원
# 추가 주문하시겠습니까? 추가 주문하시려면 0(완료) 또는 1(추가주문)을 입력하십시오.: 1
#
# 음료 번호를 입력하세요 : 4
# yuza_tea  :  2500 원
# HOT 음료는 1을, ICE 음료는 2를 입력하세요 : 2
# 주문 음료 Ice yuza_tea  :  2500 원
# 추가 주문하시겠습니까? 추가 주문하시려면 0(완료) 또는 1(추가주문)을 입력하십시오.: 0
#
# 결제방법을 입력하세요. cash는 1번, card는 2번을 입력하세요 : 2
# IC칩 방향에 맞게 카드를 꽂아주세요
#
# 주문하신 내역은
# mocha : 3000
# yuza_tea : 2500
# 총 금액은 5500원 입니다
