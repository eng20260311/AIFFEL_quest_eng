# %% [markdown]
# <a href="https://colab.research.google.com/github/eng20260311/AIFFEL_quest_eng/blob/master/Python/Py05/%EC%9D%80%ED%96%89%EA%B3%84%EC%A2%8C%EB%A7%8C%EB%93%A4%EA%B8%B0-1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Q1

# %%
#Account 클래스 만들기 : 은행이름, 예금주, 계좌번호 잔액 생성자에서는 예금주와 초기 잔액만 입력하는 클래스
import random

user_name=input('예금주의 이름을 입력하세요: ')
user_balance=int(input('계좌에 존재하는 잔액을 입력하세요: '))
class Account:
   def __init__(self, name, balance):
    self.name=name                     #예금주
    self.balance=balance               #잔액

    self.account_number = f"{random.randint(100,999)}-{random.randint(10,99)}-{random.randint(100000, 999999)}"
                                                             # '000-00-000000' 형식의 랜덤 계좌번호 생성

   def __str__(self):
    return f"Sc은행: | 계좌번호: {self.account_number} |예금주: {self.name}   | 잔액: {self.balance:,}원"
my_account=Account(user_name, user_balance)

print(my_account)
# Out:
# 예금주의 이름을 입력하세요: 김현희
# 계좌에 존재하는 잔액을 입력하세요: 50000
# Sc은행: | 계좌번호: 170-79-366904 |예금주: 김현희   | 잔액: 50,000원

# %% [markdown]
# Q2

# %%
import random


class Account:
    count=0
    def __init__(self, name, balance):
     self.name=name                     #예금주
     self.balance=balance               #잔액

     self.account_number = f"{random.randint(100,999)}-{random.randint(10,99)}-{random.randint(100000, 999999)}"
                                                            # '000-00-000000' 형식의 랜덤 계좌번호 생성

    def __str__(self):
     return f"Sc은행: | 계좌번호: {self.account_number} |예금주: {self.name}   | 잔액: {self.balance:,}원"


while True:
  user_name=input('예금주의 이름을 입력하세요(종료하려면 "quit"): ')

  if user_name=="quit" :
    print('계좌생성을 종료합니다.')
    break

  user_balance=int(input('계좌에 존재하는 잔액을 입력하세요: '))
  my_account=Account(user_name, user_balance)
  print(my_account)
  count +=1

  print(f'지금까지 {count}개의 계좌가 생성되었습니다.')
# Out:
# 예금주의 이름을 입력하세요(종료하려면 "quit"): 김현희
# 계좌에 존재하는 잔액을 입력하세요: 50000
# Sc은행: | 계좌번호: 249-75-596394 |예금주: 김현희   | 잔액: 50,000원
# 지금까지 1개의 계좌가 생성되었습니다.
# 예금주의 이름을 입력하세요(종료하려면 "quit"): 김동동
# 계좌에 존재하는 잔액을 입력하세요: 30000
# Sc은행: | 계좌번호: 992-39-157771 |예금주: 김동동   | 잔액: 30,000원
# 지금까지 2개의 계좌가 생성되었습니다.
# 예금주의 이름을 입력하세요(종료하려면 "quit"): 파송송
# 계좌에 존재하는 잔액을 입력하세요: 100000
# Sc은행: | 계좌번호: 868-26-237280 |예금주: 파송송   | 잔액: 100,000원
# 지금까지 3개의 계좌가 생성되었습니다.
# 예금주의 이름을 입력하세요(종료하려면 "quit"): quit
# 계좌생성을 종료합니다.

# %% [markdown]
# Q3

# %%
import random


class Account:
    count=0
    def __init__(self, name, balance):
     self.name=name                     #예금주
     self.balance=balance               #잔액

     self.account_number = f"{random.randint(100,999)}-{random.randint(10,99)}-{random.randint(100000, 999999)}"
                                                            # '000-00-000000' 형식의 랜덤 계좌번호 생성

    def __str__(self):
     return f"Sc은행: | 계좌번호: {self.account_number} |예금주: {self.name}   | 잔액: {self.balance:,}원"

    def get_account_num():
      print(f'지금까지 {count}개의 계좌가 생성되었습니다.')

while True:
  user_name=input('예금주의 이름을 입력하세요(종료하려면 "quit"): ')

  if user_name=="quit" :
    print('계좌생성을 종료합니다.')
    break

  user_balance=int(input('계좌에 존재하는 잔액을 입력하세요: '))
  my_account=Account(user_name, user_balance)
  print(my_account)
  count +=1


  Account.get_account_num()
# Out:
# 예금주의 이름을 입력하세요(종료하려면 "quit"): dfjdjkf
# 계좌에 존재하는 잔액을 입력하세요: 3333
# Sc은행: | 계좌번호: 530-69-202809 |예금주: dfjdjkf   | 잔액: 3,333원
# 지금까지 8개의 계좌가 생성되었습니다.
# 예금주의 이름을 입력하세요(종료하려면 "quit"): dfg
# 계좌에 존재하는 잔액을 입력하세요: 33333
# Sc은행: | 계좌번호: 921-42-256975 |예금주: dfg   | 잔액: 33,333원
# 지금까지 9개의 계좌가 생성되었습니다.
# 예금주의 이름을 입력하세요(종료하려면 "quit"): quit
# 계좌생성을 종료합니다.

# %% [markdown]
# Q4

# %%
import random


class Account:

    count=0

    def __init__(self, name, balance):
     self.name=name                     #예금주
     self.balance=balance              #잔액
     self.account_number = f"{random.randint(100,999)}-{random.randint(10,99)}-{random.randint(100000, 999999)}"
                                                            # '000-00-000000' 형식의 랜덤 계좌번호 생성
     Account.count += 1

    def __str__(self):
     return f"Sc은행: | 계좌번호: {self.account_number} |예금주: {self.name}   | 잔액: {self.balance:,}원"

    @classmethod
    def get_account_num(cls):
      print(f'지금까지 {cls.count}개의 계좌가 생성되었습니다.')

    def deposit(self, d_money):

      if d_money >= 1:
        self.balance+= d_money
        print(f'입금액은 {d_money:,}원 입니다.총 잔액은 {self.balance: ,}원 입니다. ')
      else:
        print('입금 금액은 1원 이상이어야 합니다. ')

while True:                                               #메인 실행루프
  user_name=input('\n예금주의 이름을 입력하세요(종료하려면 "quit"): ')

  if user_name=="quit" :
    print('계좌생성을 종료합니다.')
    break

  user_balance=int(input('계좌에 존재하는 잔액을 입력하세요: '))

  my_account=Account(user_name, user_balance)            #계좌 객체 생성
  print(my_account)

  d_money = int(input('입금할 금액을 입력하세요 (안 하려면 0): '))           #입금 기능
  if d_money > 0:
      my_account.deposit(d_money)
''
Account.get_account_num()                                    #전체 계좌수 출력
# Out:
# 예금주의 이름을 입력하세요(종료하려면 "quit"): 김현희
# 계좌에 존재하는 잔액을 입력하세요: 40000
# Sc은행: | 계좌번호: 828-76-900174 |예금주: 김현희   | 잔액: 40,000원
# 입금할 금액을 입력하세요 (안 하려면 0): 30000
# 입금액은 30,000원 입니다.총 잔액은  70,000원 입니다.
#
# 예금주의 이름을 입력하세요(종료하려면 "quit"): 김동동
# 계좌에 존재하는 잔액을 입력하세요: 30000
# Sc은행: | 계좌번호: 784-13-179833 |예금주: 김동동   | 잔액: 30,000원
# 입금할 금액을 입력하세요 (안 하려면 0): 10000
# 입금액은 10,000원 입니다.총 잔액은  40,000원 입니다.
#
# 예금주의 이름을 입력하세요(종료하려면 "quit"): quit
# 계좌생성을 종료합니다.
# 지금까지 2개의 계좌가 생성되었습니다.

# %% [markdown]
# Q5

# %%
import random


class Account:

    count=0

    def __init__(self, name, balance):
     self.name=name                     #예금주
     self.balance=balance              #잔액
     self.account_number = f"{random.randint(100,999)}-{random.randint(10,99)}-{random.randint(100000, 999999)}"
                                                            # '000-00-000000' 형식의 랜덤 계좌번호 생성
     Account.count += 1

    def __str__(self):
     return f"Sc은행: | 계좌번호: {self.account_number} |예금주: {self.name}   | 잔액: {self.balance:,}원"

    @classmethod
    def get_account_num(cls):
      print(f'지금까지 총{cls.count}개의 계좌가 생성되었습니다.')

    def deposit(self, d_money):

      if d_money >= 1:
        self.balance += d_money
        print(f'입금액은 {d_money:,}원 입니다.총 잔액은 {self.balance: ,}원 입니다. ')
      else:
        print('입금 금액은 1원 이상이어야 합니다. ')


    def withdraw(self, w_money):

      if w_money <= self.balance:
        self.balance -= w_money
        print(f'출금액은 {w_money:,}원입니다. 남은 잔액은 {self.balance:,}원입니다.')
        return True
      else:
        print('잔액이 부족합니다. 현재 잔액은 {self.balance:,}원입니다.')
        return False

while True:                                               #메인 실행루프
  user_name=input('\n 예금주의 이름을 입력하세요(종료하려면 "quit"): ')

  if user_name=="quit" :
    print('계좌생성을 종료합니다.')
    break

  user_balance=int(input('계좌에 존재하는 잔액을 입력하세요: '))

  my_account=Account(user_name, user_balance)            #계좌 객체 생성
  print(my_account)

  d_money = int(input('입금할 금액을 입력하세요 (안 하려면 0): '))           #입금 기능
  if d_money > 0:
      my_account.deposit(d_money)

  w_money = int(input('출금할 금액을 입력하세요 (안 하려면 0): '))            #출금 기능
  my_account.withdraw(w_money)
''
Account.get_account_num()                                    #전체 계좌수 출력
# Out:
#  예금주의 이름을 입력하세요(종료하려면 "quit"): 김현희
# 계좌에 존재하는 잔액을 입력하세요: 30000
# Sc은행: | 계좌번호: 520-97-422493 |예금주: 김현희   | 잔액: 30,000원
# 입금할 금액을 입력하세요 (안 하려면 0): 10000
# 입금액은 10,000원 입니다.총 잔액은  40,000원 입니다.
# 출금할 금액을 입력하세요 (안 하려면 0): 2000
# 출금액은 2,000원입니다. 남은 잔액은 38,000원입니다.
#
#  예금주의 이름을 입력하세요(종료하려면 "quit"): 김동동
# 계좌에 존재하는 잔액을 입력하세요: 1000000
# Sc은행: | 계좌번호: 770-49-772821 |예금주: 김동동   | 잔액: 1,000,000원
# 입금할 금액을 입력하세요 (안 하려면 0): 20000
# 입금액은 20,000원 입니다.총 잔액은  1,020,000원 입니다.
# 출금할 금액을 입력하세요 (안 하려면 0): 300000
# 출금액은 300,000원입니다. 남은 잔액은 720,000원입니다.
#
#  예금주의 이름을 입력하세요(종료하려면 "quit"): quit
# 계좌생성을 종료합니다.
# 지금까지 2개의 계좌가 생성되었습니다.

# %% [markdown]
# Q6

# %%
import random


class Account:

    count=0
    accounts = []           #생성된 계좌들을 리스트로 저장할 변수

    def __init__(self, name, balance):
     self.name=name                     #예금주
     self.balance=balance              #잔액
     self.account_number = f"{random.randint(100,999)}-{random.randint(10,99)}-{random.randint(100000, 999999)}"
                                                            # '000-00-000000' 형식의 랜덤 계좌번호 생성
     Account.count += 1

    def __str__(self):
     return f"Sc은행: | 계좌번호: {self.account_number} |예금주: {self.name}   | 잔액: {self.balance:,}원"

    @classmethod
    def get_account_num(cls):
      print(f'지금까지 총{cls.count}개의 계좌가 생성되었습니다.')

    @classmethod
    def display_info(cls):                              #저장된 계좌들을 풀어서 출력
      print()
      for account in cls.accounts:
        print(account)

    def deposit(self, d_money):

      if d_money >= 1:
        self.balance += d_money
        print(f'입금액은 {d_money:,}원 입니다.총 잔액은 {self.balance: ,}원 입니다. ')
      elif
      else:
        print('입금 금액은 1원 이상이어야 합니다. ')


    def withdraw(self, w_money):

      if w_money <= self.balance:
        self.balance -= w_money
        print(f'출금액은 {w_money:,}원입니다. 남은 잔액은 {self.balance:,}원입니다.')
        return True
      else:
        print('잔액이 부족합니다. 현재 잔액은 {self.balance:,}원입니다.')
        return False

while True:                                               #메인 실행루프
  user_name=input('\n 예금주의 이름을 입력하세요(종료하려면 "quit"): ')

  if user_name=="quit" :
    print('계좌생성을 종료합니다.')
    break



  user_balance=int(input('계좌에 존재하는 잔액을 입력하세요: '))

  my_account=Account(user_name, user_balance)            #계좌 객체 생성
  print(my_account)
  Account.accounts.append(my_account)                     #계좌 정보에 새로운 계좌 추가

  d_money = int(input('입금할 금액을 입력하세요 (안 하려면 0): '))           #입금 기능

  if d_money > 0:
      my_account.deposit(d_money)


  w_money = int(input('출금할 금액을 입력하세요 (안 하려면 0): '))            #출금 기능
  my_account.withdraw(w_money)
''
Account.get_account_num()                                    #전체 계좌수 출력




my_account.display_info()                                    #계좌 정보 출력 함수를 호출
# Out:
#  예금주의 이름을 입력하세요(종료하려면 "quit"): 김
# 계좌에 존재하는 잔액을 입력하세요: 10000
# Sc은행: | 계좌번호: 502-65-152695 |예금주: 김   | 잔액: 10,000원
# 입금할 금액을 입력하세요 (안 하려면 0): 1
# 입금액은 1원 입니다.총 잔액은  10,001원 입니다.
# 출금할 금액을 입력하세요 (안 하려면 0): 2
# 출금액은 2원입니다. 남은 잔액은 9,999원입니다.
#
#  예금주의 이름을 입력하세요(종료하려면 "quit"): 이
# 계좌에 존재하는 잔액을 입력하세요: 1
# Sc은행: | 계좌번호: 631-26-606016 |예금주: 이   | 잔액: 1원
# 입금할 금액을 입력하세요 (안 하려면 0): 1999
# 입금액은 1,999원 입니다.총 잔액은  2,000원 입니다.
# 출금할 금액을 입력하세요 (안 하려면 0): 2
# 출금액은 2원입니다. 남은 잔액은 1,998원입니다.
#
#  예금주의 이름을 입력하세요(종료하려면 "quit"): quit
# 계좌생성을 종료합니다.
# 지금까지 총2개의 계좌가 생성되었습니다.
#
# Sc은행: | 계좌번호: 502-65-152695 |예금주: 김   | 잔액: 9,999원
# Sc은행: | 계좌번호: 631-26-606016 |예금주: 이   | 잔액: 1,998원

# %% [markdown]
# **Q7**

# %%
import random


class Account:

    count=0
    accounts = []           #생성된 계좌들을 리스트로 저장할 변수

    def __init__(self, name, balance):
     self.name=name                     #예금주
     self.balance=balance              #잔액
     self.account_number = f"{random.randint(100,999)}-{random.randint(10,99)}-{random.randint(100000, 999999)}"       # '000-00-000000' 형식의 랜덤 계좌번호 생성

     self.deposit_count=0
     Account.count += 1

    def __str__(self):
     return f"Sc은행: | 계좌번호: {self.account_number} |예금주: {self.name}   | 잔액: {self.balance:,}원"

    @classmethod
    def get_account_num(cls):
      print(f'지금까지 총{cls.count}개의 계좌가 생성되었습니다.')

    @classmethod
    def display_info(cls):                              #저장된 계좌들을 풀어서 출력
      print()
      for account in cls.accounts:
        print(account)

    def deposit(self, d_money):

      if d_money >= 1:
        self.balance += d_money
        self.deposit_count += 1
        print(f'입금액은 {d_money:,}원 입니다.총 잔액은 {self.balance: ,}원 입니다. ')
        if self.deposit_count % 5 == 0:
                interest = int(self.balance * 0.01)                                           # 현재 잔액의 1%
                self.balance += interest
                print(f' 5회 입금 이자 {interest:,}원이 지급되었습니다. (총 잔액: {self.balance:,}원)')

      else:
        print('입금 금액은 1원 이상이어야 합니다. ')


    def withdraw(self, w_money):

      if w_money <= self.balance:
        self.balance -= w_money
        print(f'출금액은 {w_money:,}원입니다. 남은 잔액은 {self.balance:,}원입니다.')
        return True
      else:
        print('잔액이 부족합니다. 현재 잔액은 {self.balance:,}원입니다.')
        return False

while True:                                               #메인 실행루프
  user_name=input('\n 예금주의 이름을 입력하세요(종료하려면 "quit"): ')

  if user_name=="quit" :
    print('계좌생성을 종료합니다.')
    break



  user_balance=int(input('계좌에 존재하는 잔액을 입력하세요: '))

  my_account=Account(user_name, user_balance)            #계좌 객체 생성
  print(my_account)
  Account.accounts.append(my_account)                     #계좌 정보에 새로운 계좌 추가

  while True:
   d_money = int(input('입금할 금액을 입력하세요 (안 하려면 0): '))           #입금 기능

   if d_money > 0:
      my_account.deposit(d_money)

   else:
      break


  w_money = int(input('출금할 금액을 입력하세요 (안 하려면 0): '))            #출금 기능
  my_account.withdraw(w_money)
''
Account.get_account_num()                                    #전체 계좌수 출력




my_account.display_info()                                    #계좌 정보 출력 함수를 호출
# Out:
#  예금주의 이름을 입력하세요(종료하려면 "quit"): 김
# 계좌에 존재하는 잔액을 입력하세요: 30000
# Sc은행: | 계좌번호: 237-56-345313 |예금주: 김   | 잔액: 30,000원
# 입금할 금액을 입력하세요 (안 하려면 0): 300000
# 입금액은 300,000원 입니다.총 잔액은  330,000원 입니다.
# 입금할 금액을 입력하세요 (안 하려면 0): 200000
# 입금액은 200,000원 입니다.총 잔액은  530,000원 입니다.
# 입금할 금액을 입력하세요 (안 하려면 0): 400000
# 입금액은 400,000원 입니다.총 잔액은  930,000원 입니다.
# 입금할 금액을 입력하세요 (안 하려면 0): 1000
# 입금액은 1,000원 입니다.총 잔액은  931,000원 입니다.
# 입금할 금액을 입력하세요 (안 하려면 0): 4000
# 입금액은 4,000원 입니다.총 잔액은  935,000원 입니다.
#  5회 입금 이자 9,350원이 지급되었습니다. (총 잔액: 944,350원)
# 입금할 금액을 입력하세요 (안 하려면 0): 0
# 출금할 금액을 입력하세요 (안 하려면 0): 20000
# 출금액은 20,000원입니다. 남은 잔액은 924,350원입니다.
#
#  예금주의 이름을 입력하세요(종료하려면 "quit"): quit
# 계좌생성을 종료합니다.
# 지금까지 총1개의 계좌가 생성되었습니다.
#
# Sc은행: | 계좌번호: 237-56-345313 |예금주: 김   | 잔액: 924,350원

# %% [markdown]
# **Q8**, Q9

# %%
import random


class Account:

    count=0
    accounts = []           #생성된 계좌들을 리스트로 저장할 변수

    def __init__(self, name, balance):
     self.name=name                     #예금주
     self.balance=balance              #잔액
     self.account_number = f"{random.randint(100,999)}-{random.randint(10,99)}-{random.randint(100000, 999999)}"       # '000-00-000000' 형식의 랜덤 계좌번호 생성

     self.deposit_count=0
     Account.count += 1
     #Account.accounts.append(my_account)


    def __str__(self):
     return f"Sc은행: | 계좌번호: {self.account_number} |예금주: {self.name}   | 잔액: {self.balance:,}원"

    @classmethod
    def get_account_num(cls):
      print(f'지금까지 총{cls.count}개의 계좌가 생성되었습니다.')

    @classmethod
    def display_info(cls):                              #저장된 계좌들을 풀어서 출력
      print()
      for account in cls.accounts:
        if account.balance>=1000000:
          print(account)

    def deposit(self, d_money):

      if d_money >= 1:
        self.balance += d_money
        self.deposit_count += 1
        print(f'입금액은 {d_money:,}원 입니다.총 잔액은 {self.balance:,}원 입니다. ')
        if self.deposit_count % 5 == 0:
                interest = int(self.balance * 0.01)                                           # 현재 잔액의 1%
                self.balance += interest
                print(f' 5회 입금 이자 {interest:,}원이 지급되었습니다. (총 잔액: {self.balance:,}원)')

      else:
        print('입금 금액은 1원 이상이어야 합니다. ')


    def withdraw(self, w_money):

      if w_money <= self.balance:
        self.balance -= w_money
        print(f'출금액은 {w_money:,}원입니다. 남은 잔액은 {self.balance:,}원입니다.')
        return True
      else:
        print('잔액이 부족합니다. 현재 잔액은 {self.balance:,}원입니다.')
        return False

while True:                                               #메인 실행루프
  user_name=input('\n 예금주의 이름을 입력하세요(종료하려면 "quit"): ')

  if user_name=="quit" :
    print('계좌생성을 종료합니다.')
    break



  user_balance=int(input('계좌에 존재하는 잔액을 입력하세요: '))

  my_account=Account(user_name, user_balance)            #계좌 객체 생성
  print(my_account)
  Account.accounts.append(my_account)                     #계좌 정보에 새로운 계좌 추가

  while True:
   d_money = int(input('입금할 금액을 입력하세요 (안 하려면 0): '))           #입금 기능

   if d_money > 0:
      my_account.deposit(d_money)

   else:
      break


  w_money = int(input('출금할 금액을 입력하세요 (안 하려면 0): '))            #출금 기능

  my_account.withdraw(w_money)
''
Account.get_account_num()                                    #전체 계좌수 출력




Account.display_info()

                                   #계좌 정보 출력 함수를 호출
# Out:
#  예금주의 이름을 입력하세요(종료하려면 "quit"): 김
# 계좌에 존재하는 잔액을 입력하세요: 10000
# Sc은행: | 계좌번호: 244-27-749582 |예금주: 김   | 잔액: 10,000원
# 입금할 금액을 입력하세요 (안 하려면 0): 0
# 출금할 금액을 입력하세요 (안 하려면 0): 0
# 출금액은 0원입니다. 남은 잔액은 10,000원입니다.
#
#  예금주의 이름을 입력하세요(종료하려면 "quit"): 박
# 계좌에 존재하는 잔액을 입력하세요: 2000000
# Sc은행: | 계좌번호: 278-81-816467 |예금주: 박   | 잔액: 2,000,000원
# 입금할 금액을 입력하세요 (안 하려면 0): 0
# 출금할 금액을 입력하세요 (안 하려면 0): 0
# 출금액은 0원입니다. 남은 잔액은 2,000,000원입니다.
#
#  예금주의 이름을 입력하세요(종료하려면 "quit"): 최
# 계좌에 존재하는 잔액을 입력하세요: 3000000
# Sc은행: | 계좌번호: 159-35-800158 |예금주: 최   | 잔액: 3,000,000원
# 입금할 금액을 입력하세요 (안 하려면 0): 0
# 출금할 금액을 입력하세요 (안 하려면 0): 0
# 출금액은 0원입니다. 남은 잔액은 3,000,000원입니다.
#
#  예금주의 이름을 입력하세요(종료하려면 "quit"): quit
# 계좌생성을 종료합니다.
# 지금까지 총3개의 계좌가 생성되었습니다.
#
# Sc은행: | 계좌번호: 278-81-816467 |예금주: 박   | 잔액: 2,000,000원
# Sc은행: | 계좌번호: 159-35-800158 |예금주: 최   | 잔액: 3,000,000원

# %% [markdown]
# **Q10**

# %%
import random


class Account:

    count=0
    accounts = []           #생성된 계좌들을 리스트로 저장할 변수

    def __init__(self, name, balance):
     self.name=name                     #예금주
     self.balance=balance              #잔액
     self.account_number = f"{random.randint(100,999)}-{random.randint(10,99)}-{random.randint(100000, 999999)}"       # '000-00-000000' 형식의 랜덤 계좌번호 생성

     self.deposit_count=0
     self.history = []
     Account.count += 1
     #Account.accounts.append(my_account)


    def __str__(self):
     return f"Sc은행: | 계좌번호: {self.account_number} |예금주: {self.name}   | 잔액: {self.balance:,}원"

    @classmethod
    def get_account_num(cls):
      print(f'지금까지 총{cls.count}개의 계좌가 생성되었습니다.')

    @classmethod
    def display_info(cls):                              #저장된 계좌들을 풀어서 출력
      print()
      for account in cls.accounts:
        if account.balance>=1000000:
          print(account)

    @classmethod
    def history_info(cls):                              #저장된 계좌들을 풀어서 출력
      print()
      for account in cls.accounts:
        print(f"{account.name} 의 입출금내역")
        for row in account.history:
          print(row)
        print()

    def deposit(self, d_money):

      if d_money >= 1:
        self.balance += d_money
        self.deposit_count += 1
        print(f'입금액은 {d_money:,}원 입니다.총 잔액은 {self.balance:,}원 입니다. ')
        if self.deposit_count % 5 == 0:
          interest = int(self.balance * 0.01)                                           # 현재 잔액의 1%
          self.balance += interest
          print(f' 5회 입금 이자 {interest:,}원이 지급되었습니다. (총 잔액: {self.balance:,}원)')
        self.deposit_history(d_money)
      else:
        print('입금 금액은 1원 이상이어야 합니다. ')


    def withdraw(self, w_money):
      print(f"출금할 금액 : {w_money}")
      if w_money <= self.balance:
        self.balance -= w_money
        print(f'출금액은 {w_money:,}원입니다. 남은 잔액은 {self.balance:,}원입니다.')
        self.withdraw_history(w_money)
        return True
      else:
        print('잔액이 부족합니다. 현재 잔액은 {self.balance:,}원입니다.')
        return False

    def deposit_history(self, money):
      self.history.append(f"입금 {self.name} {self.account_number} {money} {self.balance}")

    def withdraw_history(self, money):
      self.history.append(f"출금 {self.name} {self.account_number} {money} {self.balance}")

while True:                                               #메인 실행루프
  user_name=input('\n 예금주의 이름을 입력하세요(종료하려면 "quit"): ')

  if user_name=="quit" :
    print('계좌생성을 종료합니다.')
    break



  user_balance=int(input('계좌에 존재하는 잔액을 입력하세요: '))

  my_account=Account(user_name, user_balance)            #계좌 객체 생성
  print(my_account)
  Account.accounts.append(my_account)                     #계좌 정보에 새로운 계좌 추가

  while True:
   d_money = int(input('입금할 금액을 입력하세요 (안 하려면 0): '))           #입금 기능

   if d_money > 0:
      my_account.deposit(d_money)

   else:
      break


  w_money = int(input('출금할 금액을 입력하세요 (안 하려면 0): '))            #출금 기능
  #if w_money < my_account.balance:
  my_account.withdraw(w_money)
''
Account.get_account_num()                                    #전체 계좌수 출력




Account.display_info()
Account.history_info()
# Out:
#  예금주의 이름을 입력하세요(종료하려면 "quit"): 김
# 계좌에 존재하는 잔액을 입력하세요: 100000
# Sc은행: | 계좌번호: 822-18-316838 |예금주: 김   | 잔액: 100,000원
# 입금할 금액을 입력하세요 (안 하려면 0): 1000
# 입금액은 1,000원 입니다.총 잔액은 101,000원 입니다.
# 입금할 금액을 입력하세요 (안 하려면 0): 0
# 출금할 금액을 입력하세요 (안 하려면 0): 100
# 출금할 금액 : 100
# 출금액은 100원입니다. 남은 잔액은 100,900원입니다.
#
#  예금주의 이름을 입력하세요(종료하려면 "quit"): 이
# 계좌에 존재하는 잔액을 입력하세요: 300000
# Sc은행: | 계좌번호: 933-93-641780 |예금주: 이   | 잔액: 300,000원
# 입금할 금액을 입력하세요 (안 하려면 0): 50000000
# 입금액은 50,000,000원 입니다.총 잔액은 50,300,000원 입니다.
# 입금할 금액을 입력하세요 (안 하려면 0): 0
# 출금할 금액을 입력하세요 (안 하려면 0): 100000
# 출금할 금액 : 100000
# 출금액은 100,000원입니다. 남은 잔액은 50,200,000원입니다.
#
#  예금주의 이름을 입력하세요(종료하려면 "quit"): quit
# 계좌생성을 종료합니다.
# 지금까지 총2개의 계좌가 생성되었습니다.
#
# Sc은행: | 계좌번호: 933-93-641780 |예금주: 이   | 잔액: 50,200,000원
#
# 김 의 입출금내역
# 입금 김 822-18-316838 1000 101000
# 출금 김 822-18-316838 100 100900
#
# 이 의 입출금내역
# 입금 이 933-93-641780 50000000 50300000
# 출금 이 933-93-641780 100000 50200000
